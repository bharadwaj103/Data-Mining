# %% [markdown]
# <a href="https://colab.research.google.com/github/bharadwaj103/Data-Mining/blob/main/DM_Lab_06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install https://github.com/pandas-profiling/pandas-profiling/archive/master.zip
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.9/17.9 MB 26.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 6.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 687.8/687.8 kB 22.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.8/104.8 kB 11.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 58.2 MB/s eta 0:00:00
# ...
#   Created wheel for ydata-profiling: filename=ydata_profiling-0.0.dev0-py2.py3-none-any.whl size=390960 sha256=b324d8ccba861c4f8f2a1df5c7a6eb02c73029a32f859842b12b2bbf6e07d16f
#   Stored in directory: /tmp/pip-ephem-wheel-cache-xr2zq81k/wheels/85/5d/45/8a23c7b77d2023fbc37490b8902f7fdeff5614f65d6e08b6c4
# ...
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27081 sha256=8f473f780164fc9e2bf12df75189e86a63e807225c1fd0898c3288ded4be48e1
# ...

# %%
import pandas as pd
# Load dataset from URL (Example: Titanic dataset)
data = pd.read_csv('titanic.csv')
# Display the first few rows of the dataset
data.head()
# Out:
#    Unnamed: 0  pclass  survived  \
# 0           1     1.0       1.0
# 1           2     1.0       1.0
# 2           3     1.0       0.0
# 3           4     1.0       0.0
# 4           5     1.0       0.0
#
#                                               name     sex      age  sibsp  \
# 0                    Allen, Miss. Elisabeth Walton  female  29.0000    0.0
# 1                   Allison, Master. Hudson Trevor    male   0.9167    1.0
# 2                     Allison, Miss. Helen Loraine  female   2.0000    1.0
# 3             Allison, Mr. Hudson Joshua Creighton    male  30.0000    1.0
# 4  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000    1.0
#
#    parch  ticket      fare    cabin embarked boat   body  \
# 0    0.0   24160  211.3375       B5        S    2    NaN
# 1    2.0  113781  151.5500  C22 C26        S   11    NaN
# 2    2.0  113781  151.5500  C22 C26        S  NaN    NaN
# 3    2.0  113781  151.5500  C22 C26        S  NaN  135.0
# ...

# %%
#DATA OVERVIEW
# Display basic information about the dataset
data.info()
# Summary statistics of numerical columns
data.describe()
# Check for missing values
data.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1310 entries, 0 to 1309
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1310 non-null   int64
#  1   pclass            1309 non-null   float64
#  2   survived          1309 non-null   float64
#  3   name              1309 non-null   object
#  4   sex               1309 non-null   object
#  5   age               1310 non-null   float64
#  6   sibsp             1309 non-null   float64
#  7   parch             1309 non-null   float64
#  8   ticket            1309 non-null   object
#  9   fare              1308 non-null   float64
#  10  cabin             295 non-null    object
#  11  embarked          1310 non-null   object
#  12  boat              486 non-null    object
#  13  body              121 non-null    float64
#  14  home.dest         745 non-null    object
#  15  has_cabin_number  1310 non-null   int64
# ...

# %%
#Handling Missing Values:
import pandas as pd
# Load dataset from URL (Example: Titanic dataset)
data = pd.read_csv('titanic.csv')

# Display the first few rows of the dataset to inspect column names
print(data.head())

# Handling missing values (Impute 'Age' with median and 'Embarked' with mode)
# Check if 'age' is the correct column name, if not adjust accordingly
data['age'].fillna(data['age'].median(), inplace=True)  # Changed 'Age' to 'age'

# Similarly, check for the correct column name for 'Embarked'
data['embarked'].fillna(data['embarked'].mode()[0], inplace=True) # Changed 'Embarked' to 'embarked'

# Verify that missing values are handled
print(data.isnull().sum())
# Out:
#    Unnamed: 0  pclass  survived  \
# 0           1     1.0       1.0
# 1           2     1.0       1.0
# 2           3     1.0       0.0
# 3           4     1.0       0.0
# 4           5     1.0       0.0
#
#                                               name     sex      age  sibsp  \
# 0                    Allen, Miss. Elisabeth Walton  female  29.0000    0.0
# 1                   Allison, Master. Hudson Trevor    male   0.9167    1.0
# 2                     Allison, Miss. Helen Loraine  female   2.0000    1.0
# 3             Allison, Mr. Hudson Joshua Creighton    male  30.0000    1.0
# 4  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000    1.0
#
#    parch  ticket      fare    cabin embarked boat   body  \
# 0    0.0   24160  211.3375       B5        S    2    NaN
# 1    2.0  113781  151.5500  C22 C26        S   11    NaN
# 2    2.0  113781  151.5500  C22 C26        S  NaN    NaN
# 3    2.0  113781  151.5500  C22 C26        S  NaN  135.0
# ...

# %%
#Correlation Analysis
# Correlation matrix
# Select only numerical features for correlation analysis
numerical_data = data.select_dtypes(include=['number']) # Selects only numerical columns
correlation_matrix = numerical_data.corr()  # Calculate correlation on numerical data only
import seaborn as sns
import matplotlib.pyplot as plt
# Heatmap of correlation matrix
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f',cbar=True)
plt.title('Correlation Matrix')
plt.show()

# %%
# Trend Analysis (e.g., Passenger Age vs Fare):
# Scatter plot for Age vs Fare to analyze trends
plt.figure(figsize=(8, 6))
sns.scatterplot(x='age', y='fare', data=data, hue='survived',
palette='Set1')
plt.title('Age vs Fare: Trend Analysis')
plt.xlabel('Age')
plt.ylabel('Fare')
plt.show()

# %%
# Distribution plot for Age (visualize outliers and distribution)
plt.figure(figsize=(8, 6))
sns.histplot(data['age'], bins=30, kde=True, color='skyblue')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
# Box plot to visualize outliers in Fare
plt.figure(figsize=(8, 6))
sns.boxplot(x=data['fare'], color='lightcoral')
plt.title('Fare Outliers')
plt.xlabel('Fare')
plt.show()

# %%
# Count plot for Pclass (Passenger class)
plt.figure(figsize=(8, 6))
sns.countplot(x='pclass', data=data, palette='Set2')
plt.title('Passenger Class Distribution')
plt.xlabel('Pclass')
plt.ylabel('Count')
plt.show()

# Count plot for Survived (Survival distribution)
plt.figure(figsize=(8, 6))
sns.countplot(x='survived', data=data, palette='Set2')
plt.title('Survival Distribution')
plt.xlabel('Survived')
plt.ylabel('Count')
plt.show()
# Out:
# <ipython-input-30-95c2bf017b8e>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='pclass', data=data, palette='Set2')
# <ipython-input-30-95c2bf017b8e>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='survived', data=data, palette='Set2')
